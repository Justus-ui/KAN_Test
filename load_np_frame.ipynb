# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array = np.load(r'C:\Users\prass\Documents\Code\KAN\KAN_Test\no_batch_norm\[0.5, 0.1, 0.01, 0.001, 0]_[4, 8].npy')

# %%
for decays in range(array.shape[0]):
    plt.plot(array[decays])
plt.show()
